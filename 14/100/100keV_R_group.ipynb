# %%
# %matplotlib notebook
import sys
sys.path.append("/home/oslick/jupiter/")
import read_csv
import myfunctions8 as mf8
import numpy as np
import matplotlib.pyplot as plt
import json
import math

# %%
en=100
r_range=np.arange(0,256)/10
S=[]#rings area
for r in r_range[1:]:
    s=math.pi*r**2
    S.append(s-math.pi*(r-0.01)**2)

# %%
#filename='R_ev_'+str(en)+'keV_100.csv'
#R_ev=mf8.x_ev_to_npy(filename, 102, 363)
#with open('R_ev_100keV_100.json', 'w') as f:
#    json.dump(R_ev, f)

# %%
###----real events 1-99999 ---
with open('R_ev_100keV.json') as f:
    R_ev = json.load(f)

# %%
a=np.array(R_ev['2'])
#print(a)

# %%
fig, ax = plt.subplots(figsize=(4,3), constrained_layout=True)
aa=[i for i in range(0,363)]
b=(np.array(aa))/10 
plt.hist(b[:],b[:-1], weights=a)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
with open('events_group_100keV.json') as f:
    events_group = json.load(f)

# %%
for i in range(len(events_group)):
    if len(events_group[str(i)])>0:
        R_ev_i={key:list(np.array(R_ev.get(str(key)))[1:256]/sum(np.array(R_ev.get(str(key)))[1:256])/S) 
                for key in events_group[str(i)]}
    with open('R_ev_'+str(i)+'mm_100keV.json', 'w') as f:
        json.dump(R_ev_i, f)

# %%
with open('R_ev_0mm_100keV.json') as f:
    R_ev_0 = json.load(f)
print(len(R_ev_0))
# Out:
# 39772
