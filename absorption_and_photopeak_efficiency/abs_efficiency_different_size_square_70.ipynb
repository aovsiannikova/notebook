# %%
# %matplotlib notebook
import sys
import matplotlib.pyplot as plt
import numpy as np
sys.path.append("/home/oslick/jupiter/")
import myfunctions as mf
import myfunctions8 as mf8
import read_csv
import json
from matplotlib.ticker import ScalarFormatter
import matplotlib.ticker as tick
plt.rc('font', size=10)

# %%
#efficiency={}
#for i in ['q_70_1','q_70_2','q_70_2.54', 'q_70_3']:
#    if i=='q_70_1':
#        size='7.0 x 7.0 x 1 cm'
#    if i=='q_70_2':
#        size='7.0 x 7.0 x 2 cm'
#    if i=='q_70_2.54':
#        size='7.0 x 7.0 x 2.54 cm'
#    if i=='q_70_3':
#        size='7.0 x 7.0 x 3 cm'
#    
#    efficiency[i]={}
#    nonzero=[]
#    photopeak=[]
#    for en in mf8.energy:
#        filename='counts_'+i+'_'+str(en)+'keV.csv'
#        counts=read_csv.read_csv_one(filename, datatype='int')
#        nonzero.append(len([x for x in counts if x>0])/len(counts)*100)
#        photopeak.append(len([x for x in counts if (x/en)>mf.photopeak])/len([x for x in counts if x>0])*100)
#    efficiency[i]['size']=size
#    efficiency[i]['en']=mf8.energy
#    efficiency[i]['abs_eff']=nonzero
#    efficiency[i]['ph_eff']=photopeak
#with open('eff_squre70_data.json', 'w') as f:
#    json.dump(efficiency, f)

# %%
with open('eff_squre70_data.json') as f:
    efficiency = json.load(f)

# %%
fig, ax = plt.subplots(1,2, figsize=(9,3.5), constrained_layout=True)
xaxis='energy, keV'
yaxis=['Absorption efficiency, %', 'Photo-peak efficiency, %']
en2=[20, 50, 100, 200, 500, 1000, 4000]
ticks=[[20,30,40,50,60,70,80,90,100],[10, 20, 30,40,60,80,100]]

for a in efficiency:
    ax[0].plot(efficiency[a]['en'], efficiency[a]['abs_eff'], linewidth=2, label=efficiency[a]['size'])
    ax[1].plot(efficiency[a]['en'], efficiency[a]['ph_eff'], linewidth=2, label=efficiency[a]['size'])
    
ax[0].set(ylabel=yaxis[0],yscale='log')
ax[1].set(ylabel=yaxis[1],yscale='log')

for i in ax:
    i.grid(True)
    i.set(xlabel=xaxis, xscale='log')
    i.legend()
    i.get_yaxis().set_major_formatter(tick.ScalarFormatter())

    i.get_xaxis().set_major_formatter(tick.ScalarFormatter())
    i.set_xticks(en2)
ax[0].set_yticks(ticks[0])
ax[1].set_yticks(ticks[1])

plt.show()
#plt.savefig('abs_photo_eff_sq51.pdf', format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(1,2, figsize=(9,3.5), constrained_layout=True)
for a in efficiency:
    ax[0].plot(efficiency[a]['en'], efficiency[a]['abs_eff'], linewidth=2, label=efficiency[a]['size'])
    ax[1].plot(efficiency[a]['en'], efficiency[a]['ph_eff'], linewidth=2, label=efficiency[a]['size'])
    
ax[0].set(ylabel=yaxis[0],yscale='log')
ax[1].set(ylabel=yaxis[1],yscale='log')

for i in ax:
    i.grid(True)
    i.set(xlabel=xaxis)
    i.legend()
    i.get_yaxis().set_major_formatter(tick.ScalarFormatter())
    i.get_xaxis().set_major_formatter(tick.ScalarFormatter())
ax[0].set_yticks(ticks[0])
ax[1].set_yticks(ticks[1])

plt.show()
#plt.savefig('abs_photo_eff_sq70_lin.pdf', format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="900">
